# %%
pwd
# Out:
# '/content'

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"
# Out:
#  20211025_Custom_Object_Detection_using_PyTorch_Faster_RCNN
# 'Copy of train_detect_own_dataset_tf_colab4.ipynb'
#  Final_dataset.v1i.voc.zip
#  Untitled0.ipynb

# %%
cd /content/drive/My Drive/Colab Notebooks
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
cd 20211025_Custom_Object_Detection_using_PyTorch_Faster_RCNN
# Out:
# /content/drive/My Drive/Colab Notebooks/20211025_Custom_Object_Detection_using_PyTorch_Faster_RCNN

# %%
# !python3 "src/engine.py"
# Out:
# Number of training samples: 1833
# Number of validation samples: 250
#
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
#
# EPOCH 1 of 50
# Training
# Loss: 0.2392: 100% 115/115 [05:41<00:00,  2.97s/it]
# Validating
# Loss: 0.2710: 100% 16/16 [00:21<00:00,  1.37s/it]
# Epoch #0 train loss: 0.298
# Epoch #0 validation loss: 0.218
# Took 6.064 minutes for epoch 0
#
# EPOCH 2 of 50
# Training
# Loss: 0.1684: 100% 115/115 [05:47<00:00,  3.02s/it]
# Validating
# Loss: 0.3051: 100% 16/16 [00:21<00:00,  1.37s/it]
# Epoch #1 train loss: 0.198
# Epoch #1 validation loss: 0.177
# Took 6.157 minutes for epoch 1
# SAVING MODEL COMPLETE...
#
# SAVING PLOTS COMPLETE...
#
# EPOCH 3 of 50
# Training
# Loss: 0.1623: 100% 115/115 [05:45<00:00,  3.01s/it]
# Validating
# Loss: 0.2295: 100% 16/16 [00:21<00:00,  1.37s/it]
# Epoch #2 train loss: 0.155
# Epoch #2 validation loss: 0.141
# Took 6.132 minutes for epoch 2
#
# EPOCH 4 of 50
# Training
# Loss: 0.0847: 100% 115/115 [05:45<00:00,  3.00s/it]
# Validating
# Loss: 0.2345: 100% 16/16 [00:21<00:00,  1.37s/it]
# Epoch #3 train loss: 0.129
# Epoch #3 validation loss: 0.126
# Took 6.121 minutes for epoch 3
# SAVING MODEL COMPLETE...
#
# SAVING PLOTS COMPLETE...
#
# EPOCH 5 of 50
# Training
# Loss: 0.1154:  65% 75/115 [03:45<02:00,  3.00s/it]
# Traceback (most recent call last):
#   File "src/engine.py", line 119, in <module>
#     train_loss = train(train_loader, model)
#   File "src/engine.py", line 24, in train
#     for i, data in enumerate(prog_bar):
#   File "/usr/local/lib/python3.7/dist-packages/tqdm/std.py", line 1195, in __iter__
#     for obj in iterable:
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 681, in __next__
#     data = self._next_data()
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py", line 721, in _next_data
#     data = self._dataset_fetcher.fetch(index)  # may raise StopIteration
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py", line 49, in fetch
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/usr/local/lib/python3.7/dist-packages/torch/utils/data/_utils/fetch.py", line 49, in <listcomp>
#     data = [self.dataset[idx] for idx in possibly_batched_index]
#   File "/content/drive/MyDrive/Colab Notebooks/20211025_Custom_Object_Detection_using_PyTorch_Faster_RCNN/src/datasets.py", line 97, in __getitem__
#     labels = labels)
#   File "/usr/local/lib/python3.7/dist-packages/albumentations/core/composition.py", line 205, in __call__
#     data = t(force_apply=force_apply, **data)
#   File "/usr/local/lib/python3.7/dist-packages/albumentations/core/transforms_interface.py", line 98, in __call__
#     return self.apply_with_params(params, **kwargs)
#   File "/usr/local/lib/python3.7/dist-packages/albumentations/core/transforms_interface.py", line 111, in apply_with_params
#     res[key] = target_function(arg, **dict(params, **target_dependencies))
#   File "/usr/local/lib/python3.7/dist-packages/albumentations/augmentations/geometric/rotate.py", line 33, in apply
#     return np.ascontiguousarray(np.rot90(img, factor))
# KeyboardInterrupt

# %%
import matplotlib.pyplot as plt
import cv2
# %matplotlib inline

# %%
# !pip install torchmetrics
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting torchmetrics
#   Downloading torchmetrics-0.10.3-py3-none-any.whl (529 kB)
#      |████████████████████████████████| 529 kB 17.1 MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (21.3)
# Requirement already satisfied: torch>=1.3.1 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.12.1+cu113)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (4.1.1)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from torchmetrics) (1.21.6)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging->torchmetrics) (3.0.9)
# Installing collected packages: torchmetrics
# Successfully installed torchmetrics-0.10.3

# %%
# !python3 "src/inference.py"
# Out:
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:209: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and will be removed in 0.15, please use 'weights' instead.
#   f"The parameter '{pretrained_param}' is deprecated since 0.13 and will be removed in 0.15, "
# /usr/local/lib/python3.7/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and will be removed in 0.15. The current behavior is equivalent to passing `weights=FasterRCNN_ResNet50_FPN_Weights.COCO_V1`. You can also use `weights=FasterRCNN_ResNet50_FPN_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Test instances: 507
# src/../data/test/plastic6_jpg.rf.f25baa8a3b98e4bf10f142b185fb64aa.jpg True
# src/inference.py:62: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   image = np.transpose(image, (2, 0, 1)).astype(np.float)
# Prediction count 4
# []
# src/../data/test_predictions/plastic6_jpg.jpg
# Figure(640x480)
# Image 1 done...
# --------------------------------------------------
# src/../data/test/paper520_jpg.rf.58522ab5d4337cef0e2c7ec4ed5fc37c.jpg True
# Prediction count 9
# [[ 94  31 409 551]]
# src/../data/test_predictions/paper520_jpg.jpg
# Figure(640x480)
# Image 3 done...
# --------------------------------------------------
# src/../data/test/paper484_jpg.rf.cb7be46721002f3ddefc9f40fcc4e0ca.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/paper484_jpg.jpg
# Figure(640x480)
# Image 5 done...
# --------------------------------------------------
# src/../data/test/plastic264_jpg.rf.b0a1817962a78b6ef215ba7c017940f4.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/plastic264_jpg.jpg
# Figure(640x480)
# Image 9 done...
# --------------------------------------------------
# src/../data/test/glass92_jpg.rf.62a7e0b94e8be5147fae220b67fe552b.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/glass92_jpg.jpg
# Figure(640x480)
# Image 11 done...
# --------------------------------------------------
# src/../data/test/glass142_jpg.rf.e9820fe89ead464b42642544dc1c3f30.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/glass142_jpg.jpg
# Figure(640x480)
# Image 14 done...
# --------------------------------------------------
# src/../data/test/plastic114_jpg.rf.8b8ced71cc5df007521a248f9c73f48a.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/plastic114_jpg.jpg
# Figure(640x480)
# Image 16 done...
# --------------------------------------------------
# src/../data/test/trash65_jpg.rf.06aedac70066162f4173483c3ab3ce6a.jpg True
# Prediction count 6
# []
# src/../data/test_predictions/trash65_jpg.jpg
# Figure(640x480)
# Image 19 done...
# --------------------------------------------------
# src/../data/test/paper298_jpg.rf.d8b8cf4a71a448a4d18e41bbf197297b.jpg True
# Prediction count 3
# [[  8   2 604 598]]
# src/../data/test_predictions/paper298_jpg.jpg
# Figure(640x480)
# Image 20 done...
# --------------------------------------------------
# src/../data/test/glass464_jpg.rf.1d39427790d39c17efb9f59cdf17bf33.jpg True
# Prediction count 3
# [[  0  43 640 481]]
# src/../data/test_predictions/glass464_jpg.jpg
# Figure(640x480)
# Image 21 done...
# --------------------------------------------------
# src/../data/test/plastic27_jpg.rf.c69dd16300db4281faae46e4a825a9e6.jpg True
# Prediction count 2
# [[ 55  44 566 505]]
# src/../data/test_predictions/plastic27_jpg.jpg
# Figure(640x480)
# Image 25 done...
# --------------------------------------------------
# src/../data/test/plastic351_jpg.rf.7d8a19c051fbe48043656d147d5b7a9f.jpg True
# Prediction count 3
# [[ 73 185 594 513]]
# src/../data/test_predictions/plastic351_jpg.jpg
# Figure(640x480)
# Image 27 done...
# --------------------------------------------------
# src/../data/test/cardboard136_jpg.rf.0af5ac902b95acfd9307787365fb1bd8.jpg True
# Prediction count 9
# [[168 121 383 440]]
# src/../data/test_predictions/cardboard136_jpg.jpg
# Figure(640x480)
# Image 30 done...
# --------------------------------------------------
# src/../data/test/glass229_jpg.rf.996de4bc4f5b07fc17bb19d84319bbde.jpg True
# Prediction count 5
# [[105 236 538 490]]
# src/../data/test_predictions/glass229_jpg.jpg
# Figure(640x480)
# Image 34 done...
# --------------------------------------------------
# src/../data/test/metal138_jpg.rf.d170dc782833b147d0ca63bb2721f093.jpg True
# Prediction count 1
# [[168 119 509 578]]
# src/../data/test_predictions/metal138_jpg.jpg
# Figure(640x480)
# Image 35 done...
# --------------------------------------------------
# src/../data/test/paper456_jpg.rf.a944a399e745442b9a53fb2554b9c031.jpg True
# Prediction count 33
# [[111 169 480 523]]
# src/../data/test_predictions/paper456_jpg.jpg
# Figure(640x480)
# Image 38 done...
# --------------------------------------------------
# src/../data/test/paper84_jpg.rf.c86eb6b1c7b6985af05929f665e0f0e5.jpg True
# Prediction count 3
# [[  1 125 548 630]]
# src/../data/test_predictions/paper84_jpg.jpg
# Figure(640x480)
# Image 40 done...
# --------------------------------------------------
# src/../data/test/metal129_jpg.rf.5ae285321341c3272bf4b9ea84f7a50b.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/metal129_jpg.jpg
# Figure(640x480)
# Image 44 done...
# --------------------------------------------------
# src/../data/test/metal96_jpg.rf.0697cc6dfb3c7d944db605cd940a5da8.jpg True
# Prediction count 3
# [[180 295 512 640]]
# src/../data/test_predictions/metal96_jpg.jpg
# Figure(640x480)
# Image 50 done...
# --------------------------------------------------
# src/../data/test/paper258_jpg.rf.d108a17507edd93152c206f3016ddca3.jpg True
# Prediction count 4
# [[ 59   0 523 640]]
# src/../data/test_predictions/paper258_jpg.jpg
# Figure(640x480)
# Image 53 done...
# --------------------------------------------------
# src/../data/test/cardboard194_jpg.rf.257ca2884b012cfb2e1e460e31590ba7.jpg True
# Prediction count 3
# [[ 34  84 614 541]]
# src/../data/test_predictions/cardboard194_jpg.jpg
# Figure(640x480)
# Image 54 done...
# --------------------------------------------------
# src/../data/test/metal118_jpg.rf.777f2d00791a92b2055ab83dcb898438.jpg True
# Prediction count 4
# [[ 11   0 640 609]]
# src/../data/test_predictions/metal118_jpg.jpg
# Figure(640x480)
# Image 55 done...
# --------------------------------------------------
# src/../data/test/plastic309_jpg.rf.41c6358629af8ae87b933a867fbc013b.jpg True
# Prediction count 2
# [[323 206 640 640]]
# src/../data/test_predictions/plastic309_jpg.jpg
# Figure(640x480)
# Image 58 done...
# --------------------------------------------------
# src/../data/test/paper32_jpg.rf.3808371f00f2c31cded69e14a16ac5b5.jpg True
# Prediction count 2
# [[ 71  33 525 591]]
# src/../data/test_predictions/paper32_jpg.jpg
# Figure(640x480)
# Image 59 done...
# --------------------------------------------------
# src/../data/test/plastic468_jpg.rf.4aeb3e16e2ec6943525f7edb0f6a1608.jpg True
# Prediction count 4
# [[ 33 166 590 440]]
# src/../data/test_predictions/plastic468_jpg.jpg
# Figure(640x480)
# Image 62 done...
# --------------------------------------------------
# src/../data/test/cardboard269_jpg.rf.c9cd9e3f590c3127ca885a45ea5ab19c.jpg True
# Prediction count 2
# []
# src/../data/test_predictions/cardboard269_jpg.jpg
# Figure(640x480)
# Image 63 done...
# --------------------------------------------------
# src/../data/test/paper272_jpg.rf.0ea2e45b8e881a3b952376bdd22dbbb7.jpg True
# Prediction count 1
# [[ 29 121 458 504]]
# src/../data/test_predictions/paper272_jpg.jpg
# Figure(640x480)
# Image 65 done...
# --------------------------------------------------
# src/../data/test/glass320_jpg.rf.bff706fe4bb847a3e993d0dff2e998d7.jpg True
# Prediction count 10
# [[ 39 222 528 447]]
# src/../data/test_predictions/glass320_jpg.jpg
# Figure(640x480)
# Image 69 done...
# --------------------------------------------------
# src/../data/test/metal301_jpg.rf.f7bac6d284aac063d245296b5b2a21ad.jpg True
# Prediction count 1
# [[105  15 506 562]]
# src/../data/test_predictions/metal301_jpg.jpg
# Figure(640x480)
# Image 71 done...
# --------------------------------------------------
# src/../data/test/cardboard189_jpg.rf.c12adbe15db8132c2e30006fdb3d277c.jpg True
# Prediction count 3
# [[ 17   0 542 631]]
# src/../data/test_predictions/cardboard189_jpg.jpg
# Figure(640x480)
# Image 73 done...
# --------------------------------------------------
# src/../data/test/plastic282_jpg.rf.ef82a250c699d2906e14d4bd19fb2478.jpg True
# Prediction count 2
# [[ 28   0 607 639]]
# src/../data/test_predictions/plastic282_jpg.jpg
# Figure(640x480)
# Image 75 done...
# --------------------------------------------------
# src/../data/test/metal278_jpg.rf.3c89b85e0bae5845c5c5a0025108262d.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/metal278_jpg.jpg
# Figure(640x480)
# Image 76 done...
# --------------------------------------------------
# src/../data/test/glass338_jpg.rf.5f333689be1cedd825fc6b7b675e6005.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/glass338_jpg.jpg
# Figure(640x480)
# Image 78 done...
# --------------------------------------------------
# src/../data/test/plastic289_jpg.rf.86f4c42354c0c81f69a9b54f6aef60df.jpg True
# Prediction count 4
# [[192  23 448 640]]
# src/../data/test_predictions/plastic289_jpg.jpg
# Figure(640x480)
# Image 79 done...
# --------------------------------------------------
# src/../data/test/paper368_jpg.rf.ab65318a6faf840e902ad0654487b916.jpg True
# Prediction count 28
# [[162 135 446 503]]
# src/../data/test_predictions/paper368_jpg.jpg
# Figure(640x480)
# Image 81 done...
# --------------------------------------------------
# src/../data/test/paper295_jpg.rf.e2cc0bcd6ca31a78295536ff70b58182.jpg True
# Prediction count 3
# [[ 46 134 538 519]]
# src/../data/test_predictions/paper295_jpg.jpg
# Figure(640x480)
# Image 82 done...
# --------------------------------------------------
# src/../data/test/paper16_jpg.rf.220fc1a777a84b76c72b221d36127439.jpg True
# Prediction count 1
# [[ 24   0 571 640]]
# src/../data/test_predictions/paper16_jpg.jpg
# Figure(640x480)
# Image 85 done...
# --------------------------------------------------
# src/../data/test/plastic311_jpg.rf.5dbe117ee8dc6251933c6e4f82d10260.jpg True
# Prediction count 6
# [[ 54 229 483 637]]
# src/../data/test_predictions/plastic311_jpg.jpg
# Figure(640x480)
# Image 87 done...
# --------------------------------------------------
# src/../data/test/metal182_jpg.rf.738ed16cf6bd09e08609cece1ddfa269.jpg True
# Prediction count 11
# []
# src/../data/test_predictions/metal182_jpg.jpg
# Figure(640x480)
# Image 93 done...
# --------------------------------------------------
# src/../data/test/cardboard333_jpg.rf.3b5e50ab4330a8cd3eb75903241bfe6e.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/cardboard333_jpg.jpg
# Figure(640x480)
# Image 94 done...
# --------------------------------------------------
# src/../data/test/cardboard140_jpg.rf.ea87f30addbe8eca1d576cefd01c6b01.jpg True
# Prediction count 4
# [[ 21   3 493 460]]
# src/../data/test_predictions/cardboard140_jpg.jpg
# Figure(640x480)
# Image 95 done...
# --------------------------------------------------
# src/../data/test/glass22_jpg.rf.0620efe12ad2b6cf1288b700d17a7ebf.jpg True
# Prediction count 10
# []
# src/../data/test_predictions/glass22_jpg.jpg
# Figure(640x480)
# Image 96 done...
# --------------------------------------------------
# src/../data/test/glass488_jpg.rf.febadd14d34fbcbac56f808f8ad7af92.jpg True
# Prediction count 2
# [[149  83 459 502]]
# src/../data/test_predictions/glass488_jpg.jpg
# Figure(640x480)
# Image 97 done...
# --------------------------------------------------
# src/../data/test/plastic393_jpg.rf.682f1978af620e6ec2d50de5e207bd99.jpg True
# Prediction count 2
# [[ 45 239 538 478]]
# src/../data/test_predictions/plastic393_jpg.jpg
# Figure(640x480)
# Image 100 done...
# --------------------------------------------------
# src/../data/test/metal309_jpg.rf.bf09d98478be5d14a802bb3a341d826a.jpg True
# Prediction count 2
# [[120  67 467 530]]
# src/../data/test_predictions/metal309_jpg.jpg
# Figure(640x480)
# Image 101 done...
# --------------------------------------------------
# src/../data/test/cardboard325_jpg.rf.2fe16ae05354ecb31a4132c36cd836c9.jpg True
# Prediction count 2
# [[  0   6 640 640]]
# src/../data/test_predictions/cardboard325_jpg.jpg
# Figure(640x480)
# Image 102 done...
# --------------------------------------------------
# src/../data/test/glass168_jpg.rf.c633a00c75d82501123cbbc93034cd49.jpg True
# Prediction count 26
# [[215 100 524 490]]
# src/../data/test_predictions/glass168_jpg.jpg
# Figure(640x480)
# Image 103 done...
# --------------------------------------------------
# src/../data/test/paper143_jpg.rf.6ddfbac45989135e0eb571c90ea7676e.jpg True
# Prediction count 9
# [[ 63 135 573 518]]
# src/../data/test_predictions/paper143_jpg.jpg
# Figure(640x480)
# Image 105 done...
# --------------------------------------------------
# src/../data/test/cardboard390_jpg.rf.df49e5338445b804f72d29207a30ebae.jpg True
# Prediction count 3
# [[  0   6 634 640]]
# src/../data/test_predictions/cardboard390_jpg.jpg
# Figure(640x480)
# Image 106 done...
# --------------------------------------------------
# src/../data/test/glass289_jpg.rf.b39768d8aa9f8965706a2278eeec5a92.jpg True
# Prediction count 2
# [[209 133 499 607]]
# src/../data/test_predictions/glass289_jpg.jpg
# Figure(640x480)
# Image 110 done...
# --------------------------------------------------
# src/../data/test/cardboard238_jpg.rf.55384273ee78954afa6beaaf03a5f5f3.jpg True
# Prediction count 2
# []
# src/../data/test_predictions/cardboard238_jpg.jpg
# Figure(640x480)
# Image 113 done...
# --------------------------------------------------
# src/../data/test/cardboard197_jpg.rf.ca253edf75e361324ea1b597250c655f.jpg True
# Prediction count 10
# []
# src/../data/test_predictions/cardboard197_jpg.jpg
# Figure(640x480)
# Image 117 done...
# --------------------------------------------------
# src/../data/test/cardboard196_jpg.rf.bbe11b38fc301536b521322c2ff48b25.jpg True
# Prediction count 2
# []
# src/../data/test_predictions/cardboard196_jpg.jpg
# Figure(640x480)
# Image 119 done...
# --------------------------------------------------
# src/../data/test/paper286_jpg.rf.85d17c702db74a576219ca02fadd21c8.jpg True
# Prediction count 2
# [[  0  35 636 621]]
# src/../data/test_predictions/paper286_jpg.jpg
# Figure(640x480)
# Image 120 done...
# --------------------------------------------------
# src/../data/test/glass34_jpg.rf.0de3fc91f9d16d7e2fe904360ab20474.jpg True
# Prediction count 2
# [[ 86  80 564 619]]
# src/../data/test_predictions/glass34_jpg.jpg
# Figure(640x480)
# Image 121 done...
# --------------------------------------------------
# src/../data/test/paper116_jpg.rf.52eebc7c5af1868ff9a8efbf6710fbbd.jpg True
# Prediction count 8
# [[102  43 509 501]]
# src/../data/test_predictions/paper116_jpg.jpg
# Figure(640x480)
# Image 123 done...
# --------------------------------------------------
# src/../data/test/paper408_jpg.rf.c1f5cad6deda7955f8a426bedfc73ef9.jpg True
# Prediction count 1
# [[  0   0 559 637]]
# src/../data/test_predictions/paper408_jpg.jpg
# Figure(640x480)
# Image 124 done...
# --------------------------------------------------
# src/../data/test/plastic377_jpg.rf.eebc40056de7ce066163e4f5d1b78685.jpg True
# Prediction count 1
# [[146  33 484 480]]
# src/../data/test_predictions/plastic377_jpg.jpg
# Figure(640x480)
# Image 126 done...
# --------------------------------------------------
# src/../data/test/metal166_jpg.rf.f023ca57fb6508931b3f1f0176f6a082.jpg True
# Prediction count 64
# []
# src/../data/test_predictions/metal166_jpg.jpg
# Figure(640x480)
# Image 128 done...
# --------------------------------------------------
# src/../data/test/cardboard303_jpg.rf.ffbebcd7d3618f314f8675ae214070d0.jpg True
# Prediction count 2
# [[  0  14 640 624]]
# src/../data/test_predictions/cardboard303_jpg.jpg
# Figure(640x480)
# Image 129 done...
# --------------------------------------------------
# src/../data/test/cardboard117_jpg.rf.abd3a939b937814b7b071f18c5cbd62e.jpg True
# Prediction count 10
# []
# src/../data/test_predictions/cardboard117_jpg.jpg
# Figure(640x480)
# Image 130 done...
# --------------------------------------------------
# src/../data/test/paper303_jpg.rf.786cb135e944ae0f6cf93007af6b0957.jpg True
# Prediction count 2
# [[ 32   2 626 596]]
# src/../data/test_predictions/paper303_jpg.jpg
# Figure(640x480)
# Image 132 done...
# --------------------------------------------------
# src/../data/test/glass390_jpg.rf.f1f719b0c2edec1520acba7ef8727099.jpg True
# Prediction count 4
# [[ 22 206 600 640]]
# src/../data/test_predictions/glass390_jpg.jpg
# Figure(640x480)
# Image 134 done...
# --------------------------------------------------
# src/../data/test/plastic396_jpg.rf.6d554f8686b30ba1f1cbfcf2bad8daf7.jpg True
# Prediction count 4
# [[ 14  81 615 635]]
# src/../data/test_predictions/plastic396_jpg.jpg
# Figure(640x480)
# Image 135 done...
# --------------------------------------------------
# src/../data/test/metal5_jpg.rf.ba6711de16dcb4a82f473bab523c54c5.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/metal5_jpg.jpg
# Figure(640x480)
# Image 139 done...
# --------------------------------------------------
# src/../data/test/paper459_jpg.rf.3839b192de9014732b2a41e9a777c459.jpg True
# Prediction count 1
# [[ 18 113 638 586]]
# src/../data/test_predictions/paper459_jpg.jpg
# Figure(640x480)
# Image 140 done...
# --------------------------------------------------
# src/../data/test/cardboard313_jpg.rf.c7a432a27a23c9ab158b1f4f89ed9899.jpg True
# Prediction count 2
# [[  0  10 640 640]]
# src/../data/test_predictions/cardboard313_jpg.jpg
# Figure(640x480)
# Image 141 done...
# --------------------------------------------------
# src/../data/test/cardboard53_jpg.rf.2d750671ce814e9d59b0b27906f45ebf.jpg True
# Prediction count 2
# [[  0   0 640 640]]
# src/../data/test_predictions/cardboard53_jpg.jpg
# Figure(640x480)
# Image 142 done...
# --------------------------------------------------
# src/../data/test/paper366_jpg.rf.d7e0da2ada478df44d118f515ec3ac6c.jpg True
# Prediction count 5
# [[  0  31 627 558]
#  [ 16  42 585 282]]
# src/../data/test_predictions/paper366_jpg.jpg
# Figure(640x480)
# Image 143 done...
# --------------------------------------------------
# src/../data/test/paper244_jpg.rf.9495753ad73bd699e32f706bff38bc26.jpg True
# Prediction count 1
# [[ 54  72 486 566]]
# src/../data/test_predictions/paper244_jpg.jpg
# Figure(640x480)
# Image 144 done...
# --------------------------------------------------
# src/../data/test/cardboard220_jpg.rf.cbec2c22ae74729c690f509a6e357752.jpg True
# Prediction count 9
# []
# src/../data/test_predictions/cardboard220_jpg.jpg
# Figure(640x480)
# Image 147 done...
# --------------------------------------------------
# src/../data/test/paper273_jpg.rf.81380971950db26c42432b8d3288cb0f.jpg True
# Prediction count 2
# [[ 53   0 571 640]]
# src/../data/test_predictions/paper273_jpg.jpg
# Figure(640x480)
# Image 149 done...
# --------------------------------------------------
# src/../data/test/metal140_jpg.rf.d77ffcf9ac209cded116ed68362ee7de.jpg True
# Prediction count 1
# [[144  30 522 508]]
# src/../data/test_predictions/metal140_jpg.jpg
# Figure(640x480)
# Image 150 done...
# --------------------------------------------------
# src/../data/test/paper166_jpg.rf.5b6bbaebf4791246f23f12bce67b92f6.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/paper166_jpg.jpg
# Figure(640x480)
# Image 151 done...
# --------------------------------------------------
# src/../data/test/metal162_jpg.rf.74f56a248a4dad65f60a267a7648eeae.jpg True
# Prediction count 2
# [[  0   1 637 632]]
# src/../data/test_predictions/metal162_jpg.jpg
# Figure(640x480)
# Image 152 done...
# --------------------------------------------------
# src/../data/test/glass164_jpg.rf.1bbcfd510901a04a69b051a890cb5bdc.jpg True
# Prediction count 3
# [[237  70 633 617]]
# src/../data/test_predictions/glass164_jpg.jpg
# Figure(640x480)
# Image 153 done...
# --------------------------------------------------
# src/../data/test/paper110_jpg.rf.512b1973f47135cdec81b50d316fae2d.jpg True
# Prediction count 9
# [[ 90  23 603 432]]
# src/../data/test_predictions/paper110_jpg.jpg
# Figure(640x480)
# Image 154 done...
# --------------------------------------------------
# src/../data/test/glass170_jpg.rf.bcf88a5177eadea25916902242887f01.jpg True
# Prediction count 3
# [[177 166 400 479]]
# src/../data/test_predictions/glass170_jpg.jpg
# Figure(640x480)
# Image 156 done...
# --------------------------------------------------
# src/../data/test/metal93_jpg.rf.112ded2b02eed67a6a535b1e9320d56e.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/metal93_jpg.jpg
# Figure(640x480)
# Image 157 done...
# --------------------------------------------------
# src/../data/test/glass232_jpg.rf.9076c51e408b71994c69c2b97c45ad75.jpg True
# Prediction count 8
# []
# src/../data/test_predictions/glass232_jpg.jpg
# Figure(640x480)
# Image 158 done...
# --------------------------------------------------
# src/../data/test/plastic21_jpg.rf.53617364b9a4edd1346574a4e8fd9d9a.jpg True
# Prediction count 5
# [[101 171 640 498]]
# src/../data/test_predictions/plastic21_jpg.jpg
# Figure(640x480)
# Image 160 done...
# --------------------------------------------------
# src/../data/test/plastic42_jpg.rf.03cf66fa0b44ea4f719aa5645b21753e.jpg True
# Prediction count 2
# [[149  32 623 588]]
# src/../data/test_predictions/plastic42_jpg.jpg
# Figure(640x480)
# Image 161 done...
# --------------------------------------------------
# src/../data/test/cardboard395_jpg.rf.bf17aaa1b8f8fae4c77e84a7c8889ace.jpg True
# Prediction count 2
# []
# src/../data/test_predictions/cardboard395_jpg.jpg
# Figure(640x480)
# Image 162 done...
# --------------------------------------------------
# src/../data/test/plastic111_jpg.rf.6aeaf04f83bb98990152646b3f78e5a8.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/plastic111_jpg.jpg
# Figure(640x480)
# Image 163 done...
# --------------------------------------------------
# src/../data/test/plastic340_jpg.rf.c19a4cf5f8f3f7fef9f8d637e3457715.jpg True
# Prediction count 1
# [[ 38 164 610 597]]
# src/../data/test_predictions/plastic340_jpg.jpg
# Figure(640x480)
# Image 166 done...
# --------------------------------------------------
# src/../data/test/cardboard210_jpg.rf.703c949bf0d57cddb3d330313efbd002.jpg True
# Prediction count 2
# [[  3   0 570 640]]
# src/../data/test_predictions/cardboard210_jpg.jpg
# Figure(640x480)
# Image 168 done...
# --------------------------------------------------
# src/../data/test/paper158_jpg.rf.39e50d2e36615a28a625e40b77e0f6e4.jpg True
# Prediction count 20
# [[205  79 399 544]]
# src/../data/test_predictions/paper158_jpg.jpg
# Figure(640x480)
# Image 170 done...
# --------------------------------------------------
# src/../data/test/cardboard232_jpg.rf.5bce4a16abbd08f730d7f16334f662e2.jpg True
# Prediction count 2
# [[ 39   0 640 640]]
# src/../data/test_predictions/cardboard232_jpg.jpg
# Figure(640x480)
# Image 171 done...
# --------------------------------------------------
# src/../data/test/plastic173_jpg.rf.f57c0f8050c6c023aa106a808b547102.jpg True
# Prediction count 2
# [[158 120 476 568]]
# src/../data/test_predictions/plastic173_jpg.jpg
# Figure(640x480)
# Image 172 done...
# --------------------------------------------------
# src/../data/test/plastic457_jpg.rf.0fef9c68eabb730a0735f892c6b3f606.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/plastic457_jpg.jpg
# Figure(640x480)
# Image 173 done...
# --------------------------------------------------
# src/../data/test/metal302_jpg.rf.b343bc3460c5b67cca48ddb6461f8489.jpg True
# Prediction count 15
# [[124  45 501 587]]
# src/../data/test_predictions/metal302_jpg.jpg
# Figure(640x480)
# Image 174 done...
# --------------------------------------------------
# src/../data/test/glass349_jpg.rf.a28676db97745a76d95b9456020da1c6.jpg True
# Prediction count 4
# [[149 306 559 640]]
# src/../data/test_predictions/glass349_jpg.jpg
# Figure(640x480)
# Image 175 done...
# --------------------------------------------------
# src/../data/test/plastic443_jpg.rf.591ec9b67ae86613169d8f86fc09ffb3.jpg True
# Prediction count 8
# [[130  16 597 625]]
# src/../data/test_predictions/plastic443_jpg.jpg
# Figure(640x480)
# Image 178 done...
# --------------------------------------------------
# src/../data/test/trash100_jpg.rf.e165a1988d53648468bcb9f106e6e201.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/trash100_jpg.jpg
# Figure(640x480)
# Image 179 done...
# --------------------------------------------------
# src/../data/test/paper504_jpg.rf.ba3ebb7fda3453cd209a088ef5bd787b.jpg True
# Prediction count 2
# [[  0   0 635 629]]
# src/../data/test_predictions/paper504_jpg.jpg
# Figure(640x480)
# Image 181 done...
# --------------------------------------------------
# src/../data/test/glass472_jpg.rf.9c8b8934b7ab1b3cfcce6aa51201ab63.jpg True
# Prediction count 3
# [[277   6 473 512]]
# src/../data/test_predictions/glass472_jpg.jpg
# Figure(640x480)
# Image 183 done...
# --------------------------------------------------
# src/../data/test/paper438_jpg.rf.e5b6f1290e2da1a2ec793c58e464cad6.jpg True
# Prediction count 2
# [[119  62 484 579]]
# src/../data/test_predictions/paper438_jpg.jpg
# Figure(640x480)
# Image 184 done...
# --------------------------------------------------
# src/../data/test/cardboard130_jpg.rf.7554d0d3fdd0da5b91407f516e1d303c.jpg True
# Prediction count 2
# [[ 65  65 576 554]]
# src/../data/test_predictions/cardboard130_jpg.jpg
# Figure(640x480)
# Image 185 done...
# --------------------------------------------------
# src/../data/test/glass179_jpg.rf.f2a299c16ea4c901dad0baef30252771.jpg True
# Prediction count 7
# [[  3 174 544 635]]
# src/../data/test_predictions/glass179_jpg.jpg
# Figure(640x480)
# Image 186 done...
# --------------------------------------------------
# src/../data/test/plastic296_jpg.rf.58f0dd6b0fc540765762ad14f92f2861.jpg True
# Prediction count 3
# [[ 25 201 625 509]]
# src/../data/test_predictions/plastic296_jpg.jpg
# Figure(640x480)
# Image 192 done...
# --------------------------------------------------
# src/../data/test/cardboard90_jpg.rf.4a790faae2aef836f43db591dd882ad6.jpg True
# Prediction count 2
# [[  0  10 640 640]]
# src/../data/test_predictions/cardboard90_jpg.jpg
# Figure(640x480)
# Image 199 done...
# --------------------------------------------------
# src/../data/test/glass433_jpg.rf.b1ca0eefbda7a0de872d5a26fab2c648.jpg True
# Prediction count 7
# []
# src/../data/test_predictions/glass433_jpg.jpg
# Figure(640x480)
# Image 200 done...
# --------------------------------------------------
# src/../data/test/glass374_jpg.rf.1d91d649200d01f5c949dd212219cb78.jpg True
# Prediction count 12
# []
# src/../data/test_predictions/glass374_jpg.jpg
# Figure(640x480)
# Image 202 done...
# --------------------------------------------------
# src/../data/test/glass130_jpg.rf.a54bb912df395cb591776877bb19c85a.jpg True
# Prediction count 2
# [[164 154 640 488]]
# src/../data/test_predictions/glass130_jpg.jpg
# Figure(640x480)
# Image 205 done...
# --------------------------------------------------
# src/../data/test/paper545_jpg.rf.2b983f04fd12226f23ac105e3932f481.jpg True
# Prediction count 8
# [[109 101 386 482]]
# src/../data/test_predictions/paper545_jpg.jpg
# Figure(640x480)
# Image 207 done...
# --------------------------------------------------
# src/../data/test/paper440_jpg.rf.433ff4ae00ee21caed072ece00a6ca2d.jpg True
# Prediction count 1
# [[ 17   5 632 587]]
# src/../data/test_predictions/paper440_jpg.jpg
# Figure(640x480)
# Image 208 done...
# --------------------------------------------------
# src/../data/test/cardboard400_jpg.rf.78c39184f7911fc2dbc006942d7de976.jpg True
# Prediction count 2
# [[  0   2 640 640]]
# src/../data/test_predictions/cardboard400_jpg.jpg
# Figure(640x480)
# Image 209 done...
# --------------------------------------------------
# src/../data/test/glass319_jpg.rf.d1a1befc11655c12e749a09011cd7ead.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/glass319_jpg.jpg
# Figure(640x480)
# Image 214 done...
# --------------------------------------------------
# src/../data/test/paper512_jpg.rf.c76cc001ccf6893e1701e8ac22458d42.jpg True
# Prediction count 2
# [[ 47   0 493 606]]
# src/../data/test_predictions/paper512_jpg.jpg
# Figure(640x480)
# Image 215 done...
# --------------------------------------------------
# src/../data/test/paper458_jpg.rf.bfec028a6dd89b42789f85252f80d515.jpg True
# Prediction count 1
# [[  5   0 596 628]]
# src/../data/test_predictions/paper458_jpg.jpg
# Figure(640x480)
# Image 216 done...
# --------------------------------------------------
# src/../data/test/paper12_jpg.rf.93d6ef71cf75b7b6742a735d2fff25e7.jpg True
# Prediction count 2
# [[ 24  51 606 584]]
# src/../data/test_predictions/paper12_jpg.jpg
# Figure(640x480)
# Image 219 done...
# --------------------------------------------------
# src/../data/test/cardboard70_jpg.rf.1928b68a198501cb41a5f11945606df1.jpg True
# Prediction count 5
# [[  3   3 636 433]
#  [  0   0 640 613]]
# src/../data/test_predictions/cardboard70_jpg.jpg
# Figure(640x480)
# Image 220 done...
# --------------------------------------------------
# src/../data/test/glass196_jpg.rf.1e44889401748ea93585d0d3a9adc08f.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/glass196_jpg.jpg
# Figure(640x480)
# Image 221 done...
# --------------------------------------------------
# src/../data/test/plastic231_jpg.rf.b5119e222125bc5ebdda9cb17617f618.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/plastic231_jpg.jpg
# Figure(640x480)
# Image 223 done...
# --------------------------------------------------
# src/../data/test/cardboard156_jpg.rf.31a52d6b0658eac71d20ea447388ef56.jpg True
# Prediction count 5
# [[  5   0 623 640]]
# src/../data/test_predictions/cardboard156_jpg.jpg
# Figure(640x480)
# Image 226 done...
# --------------------------------------------------
# src/../data/test/metal276_jpg.rf.4bd72fb701d7542215a005b311e02b21.jpg True
# Prediction count 2
# [[  0  18 445 487]]
# src/../data/test_predictions/metal276_jpg.jpg
# Figure(640x480)
# Image 230 done...
# --------------------------------------------------
# src/../data/test/glass185_jpg.rf.bebef5b83a97d49ce920968beacb8de6.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/glass185_jpg.jpg
# Figure(640x480)
# Image 233 done...
# --------------------------------------------------
# src/../data/test/cardboard271_jpg.rf.2475968372c2938533f2f224e730c5ad.jpg True
# Prediction count 2
# [[  0  15 640 640]]
# src/../data/test_predictions/cardboard271_jpg.jpg
# Figure(640x480)
# Image 234 done...
# --------------------------------------------------
# src/../data/test/plastic73_jpg.rf.3c849bdffae055b690f4e861fa665124.jpg True
# Prediction count 14
# [[232  69 424 600]]
# src/../data/test_predictions/plastic73_jpg.jpg
# Figure(640x480)
# Image 235 done...
# --------------------------------------------------
# src/../data/test/plastic471_jpg.rf.a7f33bc1ec46a2d5c974d2f9f0ddae5f.jpg True
# Prediction count 3
# [[117   6 466 584]]
# src/../data/test_predictions/plastic471_jpg.jpg
# Figure(640x480)
# Image 236 done...
# --------------------------------------------------
# src/../data/test/paper268_jpg.rf.d7cc8174e93effa96cb3f4d1547b2bbd.jpg True
# Prediction count 1
# [[ 63   0 505 564]]
# src/../data/test_predictions/paper268_jpg.jpg
# Figure(640x480)
# Image 237 done...
# --------------------------------------------------
# src/../data/test/plastic71_jpg.rf.7b306965d024f8a8bd8d446463cab94b.jpg True
# Prediction count 1
# [[ 53  31 573 519]]
# src/../data/test_predictions/plastic71_jpg.jpg
# Figure(640x480)
# Image 238 done...
# --------------------------------------------------
# src/../data/test/metal364_jpg.rf.68f8be2e0a079b27597425c89e438474.jpg True
# Prediction count 2
# [[167   0 596 640]]
# src/../data/test_predictions/metal364_jpg.jpg
# Figure(640x480)
# Image 241 done...
# --------------------------------------------------
# src/../data/test/trash105_jpg.rf.bc6bd05012d976af6801b544d4174d64.jpg True
# Prediction count 2
# [[149 126 485 433]]
# src/../data/test_predictions/trash105_jpg.jpg
# Figure(640x480)
# Image 242 done...
# --------------------------------------------------
# src/../data/test/metal92_jpg.rf.d8c5b4fd105cba77e724c1888d083428.jpg True
# Prediction count 2
# [[212 137 427 433]]
# src/../data/test_predictions/metal92_jpg.jpg
# Figure(640x480)
# Image 243 done...
# --------------------------------------------------
# src/../data/test/metal311_jpg.rf.170f88a3a2860b6ef14c5290803f32ba.jpg True
# Prediction count 1
# [[148 186 638 640]]
# src/../data/test_predictions/metal311_jpg.jpg
# Figure(640x480)
# Image 244 done...
# --------------------------------------------------
# src/../data/test/plastic324_jpg.rf.3929d3f612b3d4cc10d863224b8ed1c0.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/plastic324_jpg.jpg
# Figure(640x480)
# Image 246 done...
# --------------------------------------------------
# src/../data/test/plastic54_jpg.rf.872731445ace02a7d487db8ca2a04b3c.jpg True
# Prediction count 1
# [[ 67  23 526 530]]
# src/../data/test_predictions/plastic54_jpg.jpg
# Figure(640x480)
# Image 249 done...
# --------------------------------------------------
# src/../data/test/glass36_jpg.rf.adc802444b4037cc28220ec6c5152354.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/glass36_jpg.jpg
# Figure(640x480)
# Image 251 done...
# --------------------------------------------------
# src/../data/test/paper294_jpg.rf.2538ecb0a43d969ab7063da3f9ac7fa8.jpg True
# Prediction count 25
# []
# src/../data/test_predictions/paper294_jpg.jpg
# Figure(640x480)
# Image 252 done...
# --------------------------------------------------
# src/../data/test/paper151_jpg.rf.898398cd2d858fded06aae8431bfb71f.jpg True
# Prediction count 3
# [[115 134 510 476]]
# src/../data/test_predictions/paper151_jpg.jpg
# Figure(640x480)
# Image 253 done...
# --------------------------------------------------
# src/../data/test/glass127_jpg.rf.6b7aaaf88ae887c2db56c90002eedffc.jpg True
# Prediction count 2
# [[277 210 403 374]]
# src/../data/test_predictions/glass127_jpg.jpg
# Figure(640x480)
# Image 254 done...
# --------------------------------------------------
# src/../data/test/paper588_jpg.rf.81de39adbde613bca47f1a635a8e576f.jpg True
# Prediction count 4
# [[176 251 476 530]]
# src/../data/test_predictions/paper588_jpg.jpg
# Figure(640x480)
# Image 255 done...
# --------------------------------------------------
# src/../data/test/paper259_jpg.rf.33b1c3ef33b95733c70416536333d53f.jpg True
# Prediction count 3
# [[  0  67 528 632]]
# src/../data/test_predictions/paper259_jpg.jpg
# Figure(640x480)
# Image 256 done...
# --------------------------------------------------
# src/../data/test/trash135_jpg.rf.5067f4a47058633f0ed41a17897ff9b7.jpg True
# Prediction count 3
# [[ 60  91 536 574]]
# src/../data/test_predictions/trash135_jpg.jpg
# Figure(640x480)
# Image 261 done...
# --------------------------------------------------
# src/../data/test/plastic190_jpg.rf.9b23975d23ff534dd63f7462b5f8c98e.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/plastic190_jpg.jpg
# Figure(640x480)
# Image 263 done...
# --------------------------------------------------
# src/../data/test/paper364_jpg.rf.b3ee6595a52057feff251fe5e83448a7.jpg True
# Prediction count 5
# [[117  13 563 638]]
# src/../data/test_predictions/paper364_jpg.jpg
# Figure(640x480)
# Image 264 done...
# --------------------------------------------------
# src/../data/test/paper457_jpg.rf.a6df64a315fdf7a892e47cb48672219d.jpg True
# Prediction count 1
# [[  0   5 606 617]]
# src/../data/test_predictions/paper457_jpg.jpg
# Figure(640x480)
# Image 265 done...
# --------------------------------------------------
# src/../data/test/metal316_jpg.rf.6c1e5ec38cef360c7e6d73755a233b96.jpg True
# Prediction count 8
# [[211 347 639 633]]
# src/../data/test_predictions/metal316_jpg.jpg
# Figure(640x480)
# Image 269 done...
# --------------------------------------------------
# src/../data/test/plastic283_jpg.rf.9ee37f7a9772a96620bb8fba4ca83c42.jpg True
# Prediction count 1
# [[ 85   2 545 564]]
# src/../data/test_predictions/plastic283_jpg.jpg
# Figure(640x480)
# Image 272 done...
# --------------------------------------------------
# src/../data/test/glass46_jpg.rf.a4f585148f2ba2b73457839a28e8c23f.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/glass46_jpg.jpg
# Figure(640x480)
# Image 277 done...
# --------------------------------------------------
# src/../data/test/plastic252_jpg.rf.94d3535ef745bb95e65440781418f733.jpg True
# Prediction count 8
# [[106 184 579 634]]
# src/../data/test_predictions/plastic252_jpg.jpg
# Figure(640x480)
# Image 278 done...
# --------------------------------------------------
# src/../data/test/plastic265_jpg.rf.42a30e4e2cea8ab355baf56a82ee7d16.jpg True
# Prediction count 2
# [[201   0 417 429]]
# src/../data/test_predictions/plastic265_jpg.jpg
# Figure(640x480)
# Image 279 done...
# --------------------------------------------------
# src/../data/test/glass426_jpg.rf.6b86480118215bd63f13b6eb8c87bc57.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/glass426_jpg.jpg
# Figure(640x480)
# Image 280 done...
# --------------------------------------------------
# src/../data/test/glass90_jpg.rf.d281191de5657c8428dde0e02eef89bb.jpg True
# Prediction count 4
# [[170  13 478 636]]
# src/../data/test_predictions/glass90_jpg.jpg
# Figure(640x480)
# Image 284 done...
# --------------------------------------------------
# src/../data/test/plastic223_jpg.rf.f580579c3620e7b45b771b3ee743081e.jpg True
# Prediction count 3
# [[120   0 640 628]]
# src/../data/test_predictions/plastic223_jpg.jpg
# Figure(640x480)
# Image 285 done...
# --------------------------------------------------
# src/../data/test/glass140_jpg.rf.817b5abbafc46b796c4675a1f4297ba2.jpg True
# Prediction count 4
# [[147 179 394 408]]
# src/../data/test_predictions/glass140_jpg.jpg
# Figure(640x480)
# Image 287 done...
# --------------------------------------------------
# src/../data/test/plastic258_jpg.rf.640644dbb1459ed0156781f3ce024782.jpg True
# Prediction count 2
# [[175  29 640 640]]
# src/../data/test_predictions/plastic258_jpg.jpg
# Figure(640x480)
# Image 290 done...
# --------------------------------------------------
# src/../data/test/paper206_jpg.rf.7d5c143a94933b676db6ec7627fa9882.jpg True
# Prediction count 7
# [[ 20   0 493 615]]
# src/../data/test_predictions/paper206_jpg.jpg
# Figure(640x480)
# Image 293 done...
# --------------------------------------------------
# src/../data/test/cardboard58_jpg.rf.c5e78248a1a9defb2ff6cdc36036d1df.jpg True
# Prediction count 3
# [[  0  14 640 640]]
# src/../data/test_predictions/cardboard58_jpg.jpg
# Figure(640x480)
# Image 295 done...
# --------------------------------------------------
# src/../data/test/plastic242_jpg.rf.713e0de0a0e3a70d02bcf673cf9945ec.jpg True
# Prediction count 2
# [[ 75 131 576 640]]
# src/../data/test_predictions/plastic242_jpg.jpg
# Figure(640x480)
# Image 301 done...
# --------------------------------------------------
# src/../data/test/cardboard207_jpg.rf.f0edb09862ae04b7d3d143206b728288.jpg True
# Prediction count 2
# [[ 50   0 597 610]]
# src/../data/test_predictions/cardboard207_jpg.jpg
# Figure(640x480)
# Image 302 done...
# --------------------------------------------------
# src/../data/test/metal122_jpg.rf.cf1c3bf4e855ff43338850eed66a6c43.jpg True
# Prediction count 4
# [[161 151 448 511]]
# src/../data/test_predictions/metal122_jpg.jpg
# Figure(640x480)
# Image 303 done...
# --------------------------------------------------
# src/../data/test/cardboard182_jpg.rf.9d306ef9452098aa60c910b0d2f9d6eb.jpg True
# Prediction count 2
# [[  7   4 570 620]]
# src/../data/test_predictions/cardboard182_jpg.jpg
# Figure(640x480)
# Image 304 done...
# --------------------------------------------------
# src/../data/test/paper105_jpg.rf.c3c84296e44a3465aea5179d938b9f94.jpg True
# Prediction count 4
# [[  0   0 634 443]]
# src/../data/test_predictions/paper105_jpg.jpg
# Figure(640x480)
# Image 305 done...
# --------------------------------------------------
# src/../data/test/plastic428_jpg.rf.c81d579fe6ab27a9db97dd629a909660.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/plastic428_jpg.jpg
# Figure(640x480)
# Image 307 done...
# --------------------------------------------------
# src/../data/test/plastic163_jpg.rf.ed40682381eab4ef90756568dd0f7964.jpg True
# Prediction count 2
# [[ 38  98 488 550]]
# src/../data/test_predictions/plastic163_jpg.jpg
# Figure(640x480)
# Image 308 done...
# --------------------------------------------------
# src/../data/test/plastic107_jpg.rf.ce5cce90d3c768ddb384b0a1fe473857.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/plastic107_jpg.jpg
# Figure(640x480)
# Image 310 done...
# --------------------------------------------------
# src/../data/test/metal4_jpg.rf.6e86fdc4a47e13488a0522fcb740f939.jpg True
# Prediction count 9
# [[318 203 470 450]]
# src/../data/test_predictions/metal4_jpg.jpg
# Figure(640x480)
# Image 311 done...
# --------------------------------------------------
# src/../data/test/cardboard173_jpg.rf.0f44cb00dbfbd88e407d9e632e18021f.jpg True
# Prediction count 6
# []
# src/../data/test_predictions/cardboard173_jpg.jpg
# Figure(640x480)
# Image 312 done...
# --------------------------------------------------
# src/../data/test/paper469_jpg.rf.33ffbf113b9a172096853e083dbda407.jpg True
# Prediction count 2
# [[134  26 525 578]]
# src/../data/test_predictions/paper469_jpg.jpg
# Figure(640x480)
# Image 321 done...
# --------------------------------------------------
# src/../data/test/paper27_jpg.rf.7a0aa75963b8e4bb968f567a359886dc.jpg True
# Prediction count 2
# [[ 13  78 582 573]]
# src/../data/test_predictions/paper27_jpg.jpg
# Figure(640x480)
# Image 323 done...
# --------------------------------------------------
# src/../data/test/paper530_jpg.rf.b375222df4ec21547c2a52960a782625.jpg True
# Prediction count 1
# [[121 118 526 473]]
# src/../data/test_predictions/paper530_jpg.jpg
# Figure(640x480)
# Image 324 done...
# --------------------------------------------------
# src/../data/test/plastic154_jpg.rf.51e7c80f3e58ff0724c46038a45f30c4.jpg True
# Prediction count 15
# [[239 241 355 373]]
# src/../data/test_predictions/plastic154_jpg.jpg
# Figure(640x480)
# Image 329 done...
# --------------------------------------------------
# src/../data/test/paper260_jpg.rf.ed527d3caa44164c9113584089813217.jpg True
# Prediction count 1
# [[ 12  85 540 630]]
# src/../data/test_predictions/paper260_jpg.jpg
# Figure(640x480)
# Image 330 done...
# --------------------------------------------------
# src/../data/test/plastic409_jpg.rf.f73f737640acdebe43fff2d4a6803fd6.jpg True
# Prediction count 3
# [[129 178 571 472]]
# src/../data/test_predictions/plastic409_jpg.jpg
# Figure(640x480)
# Image 335 done...
# --------------------------------------------------
# src/../data/test/plastic469_jpg.rf.a3a81c65f69aa56454692b89e9acf8ba.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/plastic469_jpg.jpg
# Figure(640x480)
# Image 336 done...
# --------------------------------------------------
# src/../data/test/glass227_jpg.rf.2107c0227ccc4e9033b57aaac6dde721.jpg True
# Prediction count 3
# [[130 251 407 495]]
# src/../data/test_predictions/glass227_jpg.jpg
# Figure(640x480)
# Image 337 done...
# --------------------------------------------------
# src/../data/test/cardboard344_jpg.rf.e6b4e23c1a74c4d309b9e4dc13fc76b7.jpg True
# Prediction count 5
# [[  0  24 640 640]]
# src/../data/test_predictions/cardboard344_jpg.jpg
# Figure(640x480)
# Image 338 done...
# --------------------------------------------------
# src/../data/test/plastic474_jpg.rf.a6e93cc6e118b9de8cfbb3e705e6ea0e.jpg True
# Prediction count 2
# []
# src/../data/test_predictions/plastic474_jpg.jpg
# Figure(640x480)
# Image 340 done...
# --------------------------------------------------
# src/../data/test/glass70_jpg.rf.3be36e983360dc4fa0a889fed6366fad.jpg True
# Prediction count 3
# [[ 21 166 617 640]]
# src/../data/test_predictions/glass70_jpg.jpg
# Figure(640x480)
# Image 342 done...
# --------------------------------------------------
# src/../data/test/metal288_jpg.rf.0cb8ebdb909b240e980b01f4fa34c878.jpg True
# Prediction count 3
# [[173  68 606 633]]
# src/../data/test_predictions/metal288_jpg.jpg
# Figure(640x480)
# Image 343 done...
# --------------------------------------------------
# src/../data/test/paper394_jpg.rf.fba5ee90e536ce962276891fde6d3c3e.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/paper394_jpg.jpg
# Figure(640x480)
# Image 344 done...
# --------------------------------------------------
# src/../data/test/paper241_jpg.rf.00326697253bfec333872c63b2e0fefb.jpg True
# Prediction count 4
# [[ 39 152 589 564]]
# src/../data/test_predictions/paper241_jpg.jpg
# Figure(640x480)
# Image 346 done...
# --------------------------------------------------
# src/../data/test/paper285_jpg.rf.3531b72929285d91d9aef56d93656e56.jpg True
# Prediction count 1
# [[ 28  40 590 604]]
# src/../data/test_predictions/paper285_jpg.jpg
# Figure(640x480)
# Image 348 done...
# --------------------------------------------------
# src/../data/test/paper507_jpg.rf.03cf01e681f3ff33698669397e5274c5.jpg True
# Prediction count 2
# [[ 46  16 619 509]]
# src/../data/test_predictions/paper507_jpg.jpg
# Figure(640x480)
# Image 349 done...
# --------------------------------------------------
# src/../data/test/glass456_jpg.rf.e85eb6b04e40bd645bfee32326fa7581.jpg True
# Prediction count 3
# [[ 41 181 640 477]]
# src/../data/test_predictions/glass456_jpg.jpg
# Figure(640x480)
# Image 350 done...
# --------------------------------------------------
# src/../data/test/glass228_jpg.rf.906f430dbbae563295d58587e3d9663c.jpg True
# Prediction count 3
# [[269 208 398 383]]
# src/../data/test_predictions/glass228_jpg.jpg
# Figure(640x480)
# Image 352 done...
# --------------------------------------------------
# src/../data/test/plastic462_jpg.rf.fb70ab3a0b3179c19fbe60927f5304cf.jpg True
# Prediction count 4
# [[122 259 489 538]]
# src/../data/test_predictions/plastic462_jpg.jpg
# Figure(640x480)
# Image 357 done...
# --------------------------------------------------
# src/../data/test/paper495_jpg.rf.bafb04cf716776efbf7b4f64797c528e.jpg True
# Prediction count 1
# [[ 43  26 594 629]]
# src/../data/test_predictions/paper495_jpg.jpg
# Figure(640x480)
# Image 358 done...
# --------------------------------------------------
# src/../data/test/cardboard343_jpg.rf.241fdb5f1f94e2dfb3049b82364f4969.jpg True
# Prediction count 1
# [[  0   1 640 640]]
# src/../data/test_predictions/cardboard343_jpg.jpg
# Figure(640x480)
# Image 359 done...
# --------------------------------------------------
# src/../data/test/plastic18_jpg.rf.150e4dd0332456f14c61f4a8e66963af.jpg True
# Prediction count 2
# [[ 36  11 595 555]]
# src/../data/test_predictions/plastic18_jpg.jpg
# Figure(640x480)
# Image 360 done...
# --------------------------------------------------
# src/../data/test/plastic419_jpg.rf.29992043a5ea86f9b5ed3e9c0c635fbc.jpg True
# Prediction count 2
# [[238   0 496 560]]
# src/../data/test_predictions/plastic419_jpg.jpg
# Figure(640x480)
# Image 361 done...
# --------------------------------------------------
# src/../data/test/metal33_jpg.rf.5ef0ccb498a2df798929639ec3cdd082.jpg True
# Prediction count 3
# [[ 80   3 464 437]]
# src/../data/test_predictions/metal33_jpg.jpg
# Figure(640x480)
# Image 363 done...
# --------------------------------------------------
# src/../data/test/paper386_jpg.rf.fecba85d566d128096b6d81a18d26e76.jpg True
# Prediction count 5
# [[ 85  11 594 581]]
# src/../data/test_predictions/paper386_jpg.jpg
# Figure(640x480)
# Image 365 done...
# --------------------------------------------------
# src/../data/test/cardboard248_jpg.rf.edcab358e9fb0c4980632e6914e26712.jpg True
# Prediction count 3
# [[  3   4 635 631]]
# src/../data/test_predictions/cardboard248_jpg.jpg
# Figure(640x480)
# Image 367 done...
# --------------------------------------------------
# src/../data/test/metal42_jpg.rf.0489b553039a5020df922920e5ffad67.jpg True
# Prediction count 3
# [[  8 157 540 640]]
# src/../data/test_predictions/metal42_jpg.jpg
# Figure(640x480)
# Image 368 done...
# --------------------------------------------------
# src/../data/test/plastic452_jpg.rf.dbfb72e8b6669cb0f74754e0412cd6fa.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/plastic452_jpg.jpg
# Figure(640x480)
# Image 376 done...
# --------------------------------------------------
# src/../data/test/plastic236_jpg.rf.213ae70bfd2e1ae5a45c47cbbd30eb1b.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/plastic236_jpg.jpg
# Figure(640x480)
# Image 378 done...
# --------------------------------------------------
# src/../data/test/paper51_jpg.rf.d1f782945ce9fae8019d18ab079acc9e.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/paper51_jpg.jpg
# Figure(640x480)
# Image 379 done...
# --------------------------------------------------
# src/../data/test/metal287_jpg.rf.9083076ff0f2af51c861e68ba49de006.jpg True
# Prediction count 2
# []
# src/../data/test_predictions/metal287_jpg.jpg
# Figure(640x480)
# Image 380 done...
# --------------------------------------------------
# src/../data/test/metal312_jpg.rf.c318637bb3f603110c3d3b8a77be122c.jpg True
# Prediction count 5
# [[ 40   7 635 640]]
# src/../data/test_predictions/metal312_jpg.jpg
# Figure(640x480)
# Image 382 done...
# --------------------------------------------------
# src/../data/test/plastic293_jpg.rf.c36fa6161a092b4ed19e68b18716cfc8.jpg True
# Prediction count 2
# [[189   0 569 603]]
# src/../data/test_predictions/plastic293_jpg.jpg
# Figure(640x480)
# Image 383 done...
# --------------------------------------------------
# src/../data/test/plastic398_jpg.rf.9faee3b24b381ce0e066ea1e3975b7c0.jpg True
# Prediction count 2
# [[129  95 465 563]]
# src/../data/test_predictions/plastic398_jpg.jpg
# Figure(640x480)
# Image 384 done...
# --------------------------------------------------
# src/../data/test/metal64_jpg.rf.8e688959fb99bd575c5f0743c4761013.jpg True
# Prediction count 3
# [[  0  60 470 575]]
# src/../data/test_predictions/metal64_jpg.jpg
# Figure(640x480)
# Image 385 done...
# --------------------------------------------------
# src/../data/test/paper229_jpg.rf.7ca06b13ca3d502bc031e402320c5b4d.jpg True
# Prediction count 3
# [[  0 123 589 609]]
# src/../data/test_predictions/paper229_jpg.jpg
# Figure(640x480)
# Image 386 done...
# --------------------------------------------------
# src/../data/test/paper135_jpg.rf.e5333ced1cb1286de158422176f59cf5.jpg True
# Prediction count 1
# [[  0   0 638 640]]
# src/../data/test_predictions/paper135_jpg.jpg
# Figure(640x480)
# Image 387 done...
# --------------------------------------------------
# src/../data/test/paper378_jpg.rf.8d6920f0ed1499d6c55d9fc8de61a521.jpg True
# Prediction count 1
# [[ 19  16 574 635]]
# src/../data/test_predictions/paper378_jpg.jpg
# Figure(640x480)
# Image 389 done...
# --------------------------------------------------
# src/../data/test/cardboard72_jpg.rf.cbb723bd3b3a1d629812ba963d4d5ac4.jpg True
# Prediction count 2
# [[  0   3 640 638]]
# src/../data/test_predictions/cardboard72_jpg.jpg
# Figure(640x480)
# Image 392 done...
# --------------------------------------------------
# src/../data/test/metal39_jpg.rf.f747b64d76bd00c9d1b188285d579c08.jpg True
# Prediction count 2
# [[185 113 427 433]]
# src/../data/test_predictions/metal39_jpg.jpg
# Figure(640x480)
# Image 393 done...
# --------------------------------------------------
# src/../data/test/glass496_jpg.rf.1d81fa7399a6d606cdf8f824c530b40c.jpg True
# Prediction count 3
# [[107 109 525 401]]
# src/../data/test_predictions/glass496_jpg.jpg
# Figure(640x480)
# Image 394 done...
# --------------------------------------------------
# src/../data/test/plastic110_jpg.rf.b35d98bd73d3fc474edc331c58a62160.jpg True
# Prediction count 2
# [[ 85 137 531 525]
#  [ 61 135 448 499]]
# src/../data/test_predictions/plastic110_jpg.jpg
# Figure(640x480)
# Image 395 done...
# --------------------------------------------------
# src/../data/test/glass25_jpg.rf.85372291af4297dc137b1f1771be9123.jpg True
# Prediction count 2
# [[154 211 576 626]]
# src/../data/test_predictions/glass25_jpg.jpg
# Figure(640x480)
# Image 396 done...
# --------------------------------------------------
# src/../data/test/plastic97_jpg.rf.3886c6866cc9f42a5a4b553d10fc2aaa.jpg True
# Prediction count 2
# [[ 94  89 440 530]]
# src/../data/test_predictions/plastic97_jpg.jpg
# Figure(640x480)
# Image 397 done...
# --------------------------------------------------
# src/../data/test/paper109_jpg.rf.829edc19720b1b1aa7f5e258ae1f400a.jpg True
# Prediction count 1
# [[  4   0 546 629]]
# src/../data/test_predictions/paper109_jpg.jpg
# Figure(640x480)
# Image 399 done...
# --------------------------------------------------
# src/../data/test/glass367_jpg.rf.c16c75dec81fea0ab638d68250e528b0.jpg True
# Prediction count 4
# [[106 242 640 502]]
# src/../data/test_predictions/glass367_jpg.jpg
# Figure(640x480)
# Image 404 done...
# --------------------------------------------------
# src/../data/test/trash97_jpg.rf.2e2c45a179d7459b5d04913d40fd2d64.jpg True
# Prediction count 6
# []
# src/../data/test_predictions/trash97_jpg.jpg
# Figure(640x480)
# Image 409 done...
# --------------------------------------------------
# src/../data/test/plastic53_jpg.rf.4a2ab7f044d8938ffd3fa3c95e81d569.jpg True
# Prediction count 4
# [[ 77  47 596 627]]
# src/../data/test_predictions/plastic53_jpg.jpg
# Figure(640x480)
# Image 416 done...
# --------------------------------------------------
# src/../data/test/metal215_jpg.rf.4c2d4e1a967c6dc1a9d9996b86feb9e3.jpg True
# Prediction count 1
# [[200 215 385 464]]
# src/../data/test_predictions/metal215_jpg.jpg
# Figure(640x480)
# Image 417 done...
# --------------------------------------------------
# src/../data/test/paper441_jpg.rf.d9e82679393791942b935f96a1bac1ff.jpg True
# Prediction count 4
# [[ 55 110 549 623]]
# src/../data/test_predictions/paper441_jpg.jpg
# Figure(640x480)
# Image 419 done...
# --------------------------------------------------
# src/../data/test/plastic460_jpg.rf.4f862d12fb623597d82437c4b875841b.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/plastic460_jpg.jpg
# Figure(640x480)
# Image 420 done...
# --------------------------------------------------
# src/../data/test/trash38_jpg.rf.cd8ae2e649ed4ed311c6021b434e232a.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/trash38_jpg.jpg
# Figure(640x480)
# Image 421 done...
# --------------------------------------------------
# src/../data/test/cardboard318_jpg.rf.a97bdf30baf6eb1ea331975fff9b954a.jpg True
# Prediction count 2
# [[ 21   0 634 625]]
# src/../data/test_predictions/cardboard318_jpg.jpg
# Figure(640x480)
# Image 422 done...
# --------------------------------------------------
# src/../data/test/glass28_jpg.rf.c1cb451a7efa0e69f0629c15e72cd9e8.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/glass28_jpg.jpg
# Figure(640x480)
# Image 425 done...
# --------------------------------------------------
# src/../data/test/paper90_jpg.rf.f69ac1531ec976481f54310ea597581e.jpg True
# Prediction count 2
# [[  6   0 626 640]]
# src/../data/test_predictions/paper90_jpg.jpg
# Figure(640x480)
# Image 429 done...
# --------------------------------------------------
# src/../data/test/cardboard89_jpg.rf.361dbba11199f83ed041fb590ba86f00.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/cardboard89_jpg.jpg
# Figure(640x480)
# Image 430 done...
# --------------------------------------------------
# src/../data/test/trash44_jpg.rf.92b934da69f36a1bc5bd07df76d0a241.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/trash44_jpg.jpg
# Figure(640x480)
# Image 431 done...
# --------------------------------------------------
# src/../data/test/paper448_jpg.rf.a61ec0df2a7f8afa7f229e032b8ab4bf.jpg True
# Prediction count 1
# [[ 30 125 618 625]]
# src/../data/test_predictions/paper448_jpg.jpg
# Figure(640x480)
# Image 432 done...
# --------------------------------------------------
# src/../data/test/metal205_jpg.rf.2169848b07bd320747e3d813692651cd.jpg True
# Prediction count 4
# [[139 169 370 560]]
# src/../data/test_predictions/metal205_jpg.jpg
# Figure(640x480)
# Image 434 done...
# --------------------------------------------------
# src/../data/test/metal273_jpg.rf.c9cd657ad03b19ed21f7fe9dee107c0e.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/metal273_jpg.jpg
# Figure(640x480)
# Image 435 done...
# --------------------------------------------------
# src/../data/test/trash95_jpg.rf.e332b7c7a95c1b2573910a25c3fcb007.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/trash95_jpg.jpg
# Figure(640x480)
# Image 436 done...
# --------------------------------------------------
# src/../data/test/cardboard115_jpg.rf.46391eca407e91ea4a6a3801d8392027.jpg True
# Prediction count 1
# [[  9   7 640 640]]
# src/../data/test_predictions/cardboard115_jpg.jpg
# Figure(640x480)
# Image 437 done...
# --------------------------------------------------
# src/../data/test/glass323_jpg.rf.1175d772649d3d2f4e2d6d8742d46f7a.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/glass323_jpg.jpg
# Figure(640x480)
# Image 438 done...
# --------------------------------------------------
# src/../data/test/trash128_jpg.rf.bcf62125480484454c5952323e11c702.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/trash128_jpg.jpg
# Figure(640x480)
# Image 439 done...
# --------------------------------------------------
# src/../data/test/metal243_jpg.rf.de73c362d60985359db0b2bf656386f3.jpg True
# Prediction count 2
# [[223 292 518 640]]
# src/../data/test_predictions/metal243_jpg.jpg
# Figure(640x480)
# Image 440 done...
# --------------------------------------------------
# src/../data/test/metal11_jpg.rf.33ed24c120a3ea77294d6a3532099c06.jpg True
# Prediction count 4
# [[ 36   0 635 640]]
# src/../data/test_predictions/metal11_jpg.jpg
# Figure(640x480)
# Image 441 done...
# --------------------------------------------------
# src/../data/test/glass102_jpg.rf.15eb0bb8567556c931d4c203687794c3.jpg True
# Prediction count 3
# []
# src/../data/test_predictions/glass102_jpg.jpg
# Figure(640x480)
# Image 443 done...
# --------------------------------------------------
# src/../data/test/cardboard155_jpg.rf.e86d312ec9990f275a1183cfc53b78e0.jpg True
# Prediction count 2
# [[  7   2 640 640]]
# src/../data/test_predictions/cardboard155_jpg.jpg
# Figure(640x480)
# Image 444 done...
# --------------------------------------------------
# src/../data/test/paper8_jpg.rf.bbd5c893948b8e9016d5454fddd0381d.jpg True
# Prediction count 7
# []
# src/../data/test_predictions/paper8_jpg.jpg
# Figure(640x480)
# Image 449 done...
# --------------------------------------------------
# src/../data/test/paper70_jpg.rf.16ae36efd107145d5403c53af5224b32.jpg True
# Prediction count 3
# [[102  24 466 605]]
# src/../data/test_predictions/paper70_jpg.jpg
# Figure(640x480)
# Image 450 done...
# --------------------------------------------------
# src/../data/test/trash87_jpg.rf.d6d095949b4f9f7782bc8e09134b11f0.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/trash87_jpg.jpg
# Figure(640x480)
# Image 452 done...
# --------------------------------------------------
# src/../data/test/metal383_jpg.rf.1d7bd7b09fd0541c22257054e7ff696f.jpg True
# Prediction count 5
# [[ 37  76 639 639]]
# src/../data/test_predictions/metal383_jpg.jpg
# Figure(640x480)
# Image 453 done...
# --------------------------------------------------
# src/../data/test/glass175_jpg.rf.773c3c1efbee87f439a9c0df070e2ac3.jpg True
# Prediction count 8
# [[202 235 387 473]]
# src/../data/test_predictions/glass175_jpg.jpg
# Figure(640x480)
# Image 456 done...
# --------------------------------------------------
# src/../data/test/paper432_jpg.rf.aa7a6b134f79b1c92957fee449a34ddc.jpg True
# Prediction count 2
# [[ 20  62 640 598]]
# src/../data/test_predictions/paper432_jpg.jpg
# Figure(640x480)
# Image 462 done...
# --------------------------------------------------
# src/../data/test/paper191_jpg.rf.e9e193faf2c2a31bfba24f7566a9f9de.jpg True
# Prediction count 4
# [[ 34  10 567 623]]
# src/../data/test_predictions/paper191_jpg.jpg
# Figure(640x480)
# Image 463 done...
# --------------------------------------------------
# src/../data/test/metal228_jpg.rf.ab02a878e442eac2526395b0189c7e27.jpg True
# Prediction count 15
# [[200 174 417 479]]
# src/../data/test_predictions/metal228_jpg.jpg
# Figure(640x480)
# Image 464 done...
# --------------------------------------------------
# src/../data/test/paper399_jpg.rf.4d2a4b25611a72730fb167939fdc7633.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/paper399_jpg.jpg
# Figure(640x480)
# Image 465 done...
# --------------------------------------------------
# src/../data/test/glass415_jpg.rf.39e5ad4245158f13799d414a140bd8a2.jpg True
# Prediction count 2
# [[122 217 537 372]]
# src/../data/test_predictions/glass415_jpg.jpg
# Figure(640x480)
# Image 467 done...
# --------------------------------------------------
# src/../data/test/glass141_jpg.rf.2efaa4d7b7b0d24f7cb741f2c967e73a.jpg True
# Prediction count 2
# [[  0   0 392 620]]
# src/../data/test_predictions/glass141_jpg.jpg
# Figure(640x480)
# Image 468 done...
# --------------------------------------------------
# src/../data/test/plastic198_jpg.rf.34053da606b622d20d9eb4c43401af52.jpg True
# Prediction count 11
# [[ 23   0 607 638]]
# src/../data/test_predictions/plastic198_jpg.jpg
# Figure(640x480)
# Image 469 done...
# --------------------------------------------------
# src/../data/test/glass465_jpg.rf.6524daaf95c5d933ab4da6eb7304a715.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/glass465_jpg.jpg
# Figure(640x480)
# Image 470 done...
# --------------------------------------------------
# src/../data/test/plastic361_jpg.rf.0d5b75935c893c66554e24fff0c44375.jpg True
# Prediction count 2
# []
# src/../data/test_predictions/plastic361_jpg.jpg
# Figure(640x480)
# Image 473 done...
# --------------------------------------------------
# src/../data/test/glass316_jpg.rf.320d35e3c6434fc80a6e3a107fb31647.jpg True
# Prediction count 5
# []
# src/../data/test_predictions/glass316_jpg.jpg
# Figure(640x480)
# Image 474 done...
# --------------------------------------------------
# src/../data/test/glass424_jpg.rf.d62a936b23a2219ba8c3a59ba495b4ab.jpg True
# Prediction count 4
# []
# src/../data/test_predictions/glass424_jpg.jpg
# Figure(640x480)
# Image 478 done...
# --------------------------------------------------
# src/../data/test/cardboard396_jpg.rf.25458ae7460b3919a8fa2ef7b82868f2.jpg True
# Prediction count 2
# []
# src/../data/test_predictions/cardboard396_jpg.jpg
# Figure(640x480)
# Image 484 done...
# --------------------------------------------------
# src/../data/test/plastic189_jpg.rf.d0bbe31f4b6608f08ab599fbb199208b.jpg True
# Prediction count 3
# [[ 75 162 589 497]]
# src/../data/test_predictions/plastic189_jpg.jpg
# Figure(640x480)
# Image 488 done...
# --------------------------------------------------
# src/../data/test/glass295_jpg.rf.97a8bf68d6faec6e5127b40f291ae7e8.jpg True
# Prediction count 3
# [[129 170 439 526]]
# src/../data/test_predictions/glass295_jpg.jpg
# Figure(640x480)
# Image 489 done...
# --------------------------------------------------
# src/../data/test/paper356_jpg.rf.d8d2743d8f0396fdd1ab24190b9ec9d7.jpg True
# Prediction count 1
# [[ 44  14 603 581]]
# src/../data/test_predictions/paper356_jpg.jpg
# Figure(640x480)
# Image 491 done...
# --------------------------------------------------
# src/../data/test/paper83_jpg.rf.0f9b0a0a31e736c30181d1080b9b6086.jpg True
# Prediction count 1
# [[  5   0 627 628]]
# src/../data/test_predictions/paper83_jpg.jpg
# Figure(640x480)
# Image 497 done...
# --------------------------------------------------
# src/../data/test/cardboard25_jpg.rf.a6bbb6d113730c40fc9cd760b15f2cf6.jpg True
# Prediction count 3
# [[  0   0 632 640]]
# src/../data/test_predictions/cardboard25_jpg.jpg
# Figure(640x480)
# Image 498 done...
# --------------------------------------------------
# src/../data/test/cardboard253_jpg.rf.ab1b5178a7ef66bea5531ac5dda8a684.jpg True
# Prediction count 5
# [[  7   2 640 640]]
# src/../data/test_predictions/cardboard253_jpg.jpg
# Figure(640x480)
# Image 501 done...
# --------------------------------------------------
# src/../data/test/trash47_jpg.rf.ca42adff94f130f7fee412ca82b3d54b.jpg True
# Prediction count 11
# [[121   0 481 594]]
# src/../data/test_predictions/trash47_jpg.jpg
# Figure(640x480)
# Image 503 done...
# --------------------------------------------------
# src/../data/test/Screen Shot 2022-11-28 at 9.59.09 AM.png True
# Prediction count 16
# [[ 16   0 336 294]
#  [452 345 678 507]
#  [114 413 301 527]
#  [ 55  10 700 325]
#  [346  10 681 300]]
# src/../data/test_predictions/Screen Shot 2022-11-28 at 9.jpg
# Figure(640x480)
# Image 505 done...
# --------------------------------------------------
# src/../data/test/aaaaa.png True
# Prediction count 11
# [[557 466 776 626]
#  [110  98 475 416]]
# src/../data/test_predictions/aaaaa.jpg
# Figure(640x480)
# Image 506 done...
# --------------------------------------------------
# src/../data/test/bbbbb.png True
# Prediction count 17
# [[476  77 755 274]
#  [ 82 468 227 710]
#  [ 63 136 376 316]
#  [457 440 721 685]]
# src/../data/test_predictions/bbbbb.jpg
# Figure(640x480)
# Image 507 done...
# --------------------------------------------------
# {'map': tensor(0.0064),
#  'map_50': tensor(0.0390),
#  'map_75': tensor(0.),
#  'map_large': tensor(0.0064),
#  'map_medium': tensor(-1.),
#  'map_per_class': tensor(-1.),
#  'map_small': tensor(-1.),
#  'mar_1': tensor(0.),
#  'mar_10': tensor(0.0044),
#  'mar_100': tensor(0.0167),
#  'mar_100_per_class': tensor(-1.),
#  'mar_large': tensor(0.0167),
#  'mar_medium': tensor(-1.),
#  'mar_small': tensor(-1.)}
# TEST PREDICTIONS COMPLETE
